-- %% [markdown]
-- # [EmployeeDirectoryDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [EmployeeDirectoryDB]    Script Date: 02-09-2025 21:22:49 ******/
CREATE DATABASE [EmployeeDirectoryDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'EmployeeDirectoryDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\EmployeeDirectoryDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'EmployeeDirectoryDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\EmployeeDirectoryDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [EmployeeDirectoryDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [EmployeeDirectoryDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [EmployeeDirectoryDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET RECOVERY FULL 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET  MULTI_USER 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [EmployeeDirectoryDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [EmployeeDirectoryDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'EmployeeDirectoryDB', N'ON'
GO
ALTER DATABASE [EmployeeDirectoryDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [EmployeeDirectoryDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Departments]

-- %%
USE [EmployeeDirectoryDB]
GO

-- %%
/****** Object:  Table [dbo].[Departments]    Script Date: 02-09-2025 21:22:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Departments](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[DepartmentId] [varchar](10) NULL,
	[DepartmentName] [nvarchar](100) NOT NULL,
	[Location] [nvarchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Employees]

-- %%
/****** Object:  Table [dbo].[Employees]    Script Date: 02-09-2025 21:22:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employees](
	[EmployeeId] [int] NOT NULL,
	[FullName] [nvarchar](100) NULL,
	[Department] [nvarchar](100) NULL,
	[Email] [nvarchar](150) NULL,
	[Phone] [nvarchar](20) NULL,
	[HireDate] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[EmployeeId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sp_DeleteDepartmentDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_DeleteDepartmentDetails]    Script Date: 02-09-2025 21:22:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[sp_DeleteDepartmentDetails]
 @DepartmentId INT
AS
BEGIN
  DELETE FROM Departments
  WHERE DepartmentId=@DepartmentId

END
GO

-- %% [markdown]
-- # [dbo].[sp_DeleteEmployeeDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_DeleteEmployeeDetails]    Script Date: 02-09-2025 21:22:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_DeleteEmployeeDetails]
    @EmployeeId INT
AS
BEGIN
    DELETE FROM Employees
    WHERE EmployeeId = @EmployeeId;
END
GO

-- %% [markdown]
-- # [dbo].[sp_GetDepartmentData]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_GetDepartmentData]    Script Date: 02-09-2025 21:22:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[sp_GetDepartmentData]
AS
BEGIN 
   SELECT * FROM Departments
END
GO

-- %% [markdown]
-- # [dbo].[sp_GetEmployeeDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_GetEmployeeDetails]    Script Date: 02-09-2025 21:22:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_GetEmployeeDetails]
AS
BEGIN
    

    SELECT 
        EmployeeId,
        FullName,
        Department,
        Email,
        Phone,
        CAST(HireDate AS VARCHAR(12)) HireDate
    FROM Employees;
END
GO

-- %% [markdown]
-- # [dbo].[sp_SaveDepartmentData]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_SaveDepartmentData]    Script Date: 02-09-2025 21:22:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[sp_SaveDepartmentData]
	-- Add the parameters for the stored procedure here
	   @DepartmentId INT,
       @DepartmentName NVARCHAR(100),
       @Location NVARCHAR(100)
	
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	   INSERT Departments (DepartmentId, DepartmentName, Location)
       VALUES (@DepartmentId, @DepartmentName, @Location);
END
GO

-- %% [markdown]
-- # [dbo].[sp_SaveEmployeeDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_SaveEmployeeDetails]    Script Date: 02-09-2025 21:22:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_SaveEmployeeDetails]
    @EmployeeId INT,
    @FullName NVARCHAR(100),
    @Department NVARCHAR(100),
    @Email NVARCHAR(150),
    @Phone NVARCHAR(20),
    @HireDate DATE
AS
BEGIN
    INSERT INTO Employees (EmployeeId, FullName, Department, Email, Phone, HireDate)
    VALUES (@EmployeeId, @FullName, @Department, @Email, @Phone, @HireDate);
END
GO

-- %% [markdown]
-- # [dbo].[sp_UpdateDepartmentData]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_UpdateDepartmentData]    Script Date: 02-09-2025 21:22:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_UpdateDepartmentData]
    @DepartmentId INT,
    @DepartmentName NVARCHAR(100),
    @Location NVARCHAR(100)
AS
BEGIN
    UPDATE Departments
    SET DepartmentName = @DepartmentName,
        Location = @Location
    WHERE DepartmentId = @DepartmentId;
END
GO

-- %% [markdown]
-- # [dbo].[sp_UpdateEmployeeDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_UpdateEmployeeDetails]    Script Date: 02-09-2025 21:22:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_UpdateEmployeeDetails]
    @EmployeeId INT,
    @FullName NVARCHAR(100),
    @Department NVARCHAR(100),
    @Email NVARCHAR(150),
    @Phone NVARCHAR(20),
    @HireDate NVARCHAR(12)
AS
BEGIN
    UPDATE Employees
    SET 
        FullName   = @FullName,
        Department = @Department,
        Email      = @Email,
        Phone      = @Phone,
        HireDate   = @HireDate
    WHERE EmployeeId = @EmployeeId;
END
GO

-- %% [markdown]
-- # [EmployeeDirectoryDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [EmployeeDirectoryDB] SET  READ_WRITE 
GO
